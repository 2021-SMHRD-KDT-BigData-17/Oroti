# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('/content/장애별 직군 인구수.xlsx')

# %%
data_nan = data.replace(' ', np.nan)
data_nan.isnull().sum()
# Out:
# pid                      1731
# gender                   1731
# type15                   1731
# job001_job_code1         1731
# aage06                    729
# job001_satisfaction_1    1731
# job001_satisfaction_2    1731
# dtype: int64

# %%
data_cleaned = data_nan.dropna(subset=['pid'])
data_cleaned = data_cleaned.dropna(subset=['aage06'])
data_cleaned = data_cleaned.drop(data_cleaned[data_cleaned['job001_job_code1'] == 999.0].index)
data_cleaned.isnull().sum()
# Out:
# pid                      0
# gender                   0
# type15                   0
# job001_job_code1         0
# aage06                   0
# job001_satisfaction_1    0
# job001_satisfaction_2    0
# dtype: int64

# %%
data1 = data_cleaned.loc[:,'pid':'aage06']
data1
data2 = data_cleaned.loc[:,'job001_satisfaction_1':'job001_satisfaction_2']
data2
# Out:
#       job001_satisfaction_1  job001_satisfaction_2
# 1                       3.0                    3.0
# 2                       3.0                    3.0
# 3                       3.0                    3.0
# 5                       3.0                    3.0
# 6                       4.0                    4.0
# ...                     ...                    ...
# 2838                    5.0                    4.0
# 2839                    3.0                    4.0
# 2842                    4.0                    4.0
# 2844                    3.0                    3.0
# 2845                    4.0                    4.0
#
# [2363 rows x 2 columns]

# %%
data2['average_satisfaction'] = (data2['job001_satisfaction_1'] + data2['job001_satisfaction_2']) / 2
data1['satisfaction'] = data2['average_satisfaction']
data1
# Out:
# <ipython-input-13-59157023a212>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['average_satisfaction'] = (data2['job001_satisfaction_1'] + data2['job001_satisfaction_2']) / 2
# <ipython-input-13-59157023a212>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['satisfaction'] = data2['average_satisfaction']
#             pid  gender  type15  job001_job_code1  aage06  satisfaction
# 1       16329.0     1.0    12.0               7.0     5.0           3.0
# ...

# %%
print(data1['job001_job_code1'].unique())
# Out:
# [7. 3. 5. 8. 2. 4. 9. 1. 6.]

# %%
import pandas as pd

# gender가 1.0인 데이터
gender_1 = data1[data1['gender'] == 1.0]

# gender가 2.0인 데이터
gender_2 = data1[data1['gender'] == 2.0]

# 성별이 남자고 장애별로 나눈 데이터
gender_1_obstc1 = gender_1[gender_1['type15'] == 1.0]
gender_1_obstc2 = gender_1[gender_1['type15'] == 2.0]
gender_1_obstc3 = gender_1[gender_1['type15'] == 3.0]
gender_1_obstc4 = gender_1[gender_1['type15'] == 4.0]
gender_1_obstc5 = gender_1[gender_1['type15'] == 5.0]
gender_1_obstc6 = gender_1[gender_1['type15'] == 6.0]
gender_1_obstc7 = gender_1[gender_1['type15'] == 7.0]
gender_1_obstc8 = gender_1[gender_1['type15'] == 8.0]
gender_1_obstc9 = gender_1[gender_1['type15'] == 9.0]
gender_1_obstc10 = gender_1[gender_1['type15'] == 10.0]
gender_1_obstc11 = gender_1[gender_1['type15'] == 11.0]
gender_1_obstc12 = gender_1[gender_1['type15'] == 12.0]
gender_1_obstc13 = gender_1[gender_1['type15'] == 13.0]
gender_1_obstc14 = gender_1[gender_1['type15'] == 14.0]
gender_1_obstc15 = gender_1[gender_1['type15'] == 15.0]

# 성별이 여자고 장애별로 나눈 데이터
gender_2_obstc1 = gender_2[gender_2['type15'] == 1.0]
gender_2_obstc2 = gender_2[gender_2['type15'] == 2.0]
gender_2_obstc3 = gender_2[gender_2['type15'] == 3.0]
gender_2_obstc4 = gender_2[gender_2['type15'] == 4.0]
gender_2_obstc5 = gender_2[gender_2['type15'] == 5.0]
gender_2_obstc6 = gender_2[gender_2['type15'] == 6.0]
gender_2_obstc7 = gender_2[gender_2['type15'] == 7.0]
gender_2_obstc8 = gender_2[gender_2['type15'] == 8.0]
gender_2_obstc9 = gender_2[gender_2['type15'] == 9.0]
gender_2_obstc10 = gender_2[gender_2['type15'] == 10.0]
gender_2_obstc11 = gender_2[gender_2['type15'] == 11.0]
gender_2_obstc12 = gender_2[gender_2['type15'] == 12.0]
gender_2_obstc13 = gender_2[gender_2['type15'] == 13.0]
gender_2_obstc14 = gender_2[gender_2['type15'] == 14.0]
gender_2_obstc15 = gender_2[gender_2['type15'] == 15.0]





# 성별이 남자고 1번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc1_job1 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 1.0]
gender_1_obstc1_job2 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 2.0]
gender_1_obstc1_job3 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 3.0]
gender_1_obstc1_job4 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 4.0]
gender_1_obstc1_job5 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 5.0]
gender_1_obstc1_job6 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 6.0]
gender_1_obstc1_job7 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 7.0]
gender_1_obstc1_job8 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 8.0]
gender_1_obstc1_job9 = gender_1_obstc1[gender_1_obstc1['job001_job_code1'] == 9.0]

# 성별이 남자고 2번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc2_job1 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 1.0]
gender_1_obstc2_job2 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 2.0]
gender_1_obstc2_job3 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 3.0]
gender_1_obstc2_job4 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 4.0]
gender_1_obstc2_job5 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 5.0]
gender_1_obstc2_job6 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 6.0]
gender_1_obstc2_job7 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 7.0]
gender_1_obstc2_job8 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 8.0]
gender_1_obstc2_job9 = gender_1_obstc2[gender_1_obstc2['job001_job_code1'] == 9.0]

# 성별이 남자고 3번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc3_job1 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 1.0]
gender_1_obstc3_job2 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 2.0]
gender_1_obstc3_job3 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 3.0]
gender_1_obstc3_job4 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 4.0]
gender_1_obstc3_job5 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 5.0]
gender_1_obstc3_job6 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 6.0]
gender_1_obstc3_job7 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 7.0]
gender_1_obstc3_job8 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 8.0]
gender_1_obstc3_job9 = gender_1_obstc3[gender_1_obstc3['job001_job_code1'] == 9.0]

# 성별이 남자고 4번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc4_job1 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 1.0]
gender_1_obstc4_job2 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 2.0]
gender_1_obstc4_job3 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 3.0]
gender_1_obstc4_job4 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 4.0]
gender_1_obstc4_job5 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 5.0]
gender_1_obstc4_job6 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 6.0]
gender_1_obstc4_job7 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 7.0]
gender_1_obstc4_job8 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 8.0]
gender_1_obstc4_job9 = gender_1_obstc4[gender_1_obstc4['job001_job_code1'] == 9.0]

# 성별이 남자고 5번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc5_job1 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 1.0]
gender_1_obstc5_job2 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 2.0]
gender_1_obstc5_job3 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 3.0]
gender_1_obstc5_job4 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 4.0]
gender_1_obstc5_job5 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 5.0]
gender_1_obstc5_job6 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 6.0]
gender_1_obstc5_job7 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 7.0]
gender_1_obstc5_job8 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 8.0]
gender_1_obstc5_job9 = gender_1_obstc5[gender_1_obstc5['job001_job_code1'] == 9.0]

# 성별이 남자고 6번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc6_job1 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 1.0]
gender_1_obstc6_job2 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 2.0]
gender_1_obstc6_job3 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 3.0]
gender_1_obstc6_job4 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 4.0]
gender_1_obstc6_job5 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 5.0]
gender_1_obstc6_job6 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 6.0]
gender_1_obstc6_job7 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 7.0]
gender_1_obstc6_job8 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 8.0]
gender_1_obstc6_job9 = gender_1_obstc6[gender_1_obstc6['job001_job_code1'] == 9.0]

# 성별이 남자고 7번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc7_job1 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 1.0]
gender_1_obstc7_job2 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 2.0]
gender_1_obstc7_job3 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 3.0]
gender_1_obstc7_job4 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 4.0]
gender_1_obstc7_job5 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 5.0]
gender_1_obstc7_job6 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 6.0]
gender_1_obstc7_job7 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 7.0]
gender_1_obstc7_job8 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 8.0]
gender_1_obstc7_job9 = gender_1_obstc7[gender_1_obstc7['job001_job_code1'] == 9.0]

# 성별이 남자고 8번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc8_job1 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 1.0]
gender_1_obstc8_job2 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 2.0]
gender_1_obstc8_job3 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 3.0]
gender_1_obstc8_job4 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 4.0]
gender_1_obstc8_job5 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 5.0]
gender_1_obstc8_job6 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 6.0]
gender_1_obstc8_job7 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 7.0]
gender_1_obstc8_job8 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 8.0]
gender_1_obstc8_job9 = gender_1_obstc8[gender_1_obstc8['job001_job_code1'] == 9.0]

# 성별이 남자고 9번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc9_job1 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 1.0]
gender_1_obstc9_job2 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 2.0]
gender_1_obstc9_job3 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 3.0]
gender_1_obstc9_job4 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 4.0]
gender_1_obstc9_job5 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 5.0]
gender_1_obstc9_job6 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 6.0]
gender_1_obstc9_job7 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 7.0]
gender_1_obstc9_job8 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 8.0]
gender_1_obstc9_job9 = gender_1_obstc9[gender_1_obstc9['job001_job_code1'] == 9.0]

# 성별이 남자고 10번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc10_job1 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 1.0]
gender_1_obstc10_job2 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 2.0]
gender_1_obstc10_job3 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 3.0]
gender_1_obstc10_job4 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 4.0]
gender_1_obstc10_job5 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 5.0]
gender_1_obstc10_job6 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 6.0]
gender_1_obstc10_job7 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 7.0]
gender_1_obstc10_job8 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 8.0]
gender_1_obstc10_job9 = gender_1_obstc10[gender_1_obstc10['job001_job_code1'] == 9.0]

# 성별이 남자고 11번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc11_job1 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 1.0]
gender_1_obstc11_job2 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 2.0]
gender_1_obstc11_job3 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 3.0]
gender_1_obstc11_job4 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 4.0]
gender_1_obstc11_job5 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 5.0]
gender_1_obstc11_job6 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 6.0]
gender_1_obstc11_job7 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 7.0]
gender_1_obstc11_job8 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 8.0]
gender_1_obstc11_job9 = gender_1_obstc11[gender_1_obstc11['job001_job_code1'] == 9.0]

# 성별이 남자고 12번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc12_job1 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 1.0]
gender_1_obstc12_job2 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 2.0]
gender_1_obstc12_job3 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 3.0]
gender_1_obstc12_job4 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 4.0]
gender_1_obstc12_job5 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 5.0]
gender_1_obstc12_job6 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 6.0]
gender_1_obstc12_job7 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 7.0]
gender_1_obstc12_job8 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 8.0]
gender_1_obstc12_job9 = gender_1_obstc12[gender_1_obstc12['job001_job_code1'] == 9.0]

# 성별이 남자고 13번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc13_job1 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 1.0]
gender_1_obstc13_job2 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 2.0]
gender_1_obstc13_job3 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 3.0]
gender_1_obstc13_job4 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 4.0]
gender_1_obstc13_job5 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 5.0]
gender_1_obstc13_job6 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 6.0]
gender_1_obstc13_job7 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 7.0]
gender_1_obstc13_job8 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 8.0]
gender_1_obstc13_job9 = gender_1_obstc13[gender_1_obstc13['job001_job_code1'] == 9.0]

# 성별이 남자고 14번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc14_job1 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 1.0]
gender_1_obstc14_job2 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 2.0]
gender_1_obstc14_job3 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 3.0]
gender_1_obstc14_job4 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 4.0]
gender_1_obstc14_job5 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 5.0]
gender_1_obstc14_job6 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 6.0]
gender_1_obstc14_job7 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 7.0]
gender_1_obstc14_job8 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 8.0]
gender_1_obstc14_job9 = gender_1_obstc14[gender_1_obstc14['job001_job_code1'] == 9.0]

# 성별이 남자고 15번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_1_obstc15_job1 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 1.0]
gender_1_obstc15_job2 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 2.0]
gender_1_obstc15_job3 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 3.0]
gender_1_obstc15_job4 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 4.0]
gender_1_obstc15_job5 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 5.0]
gender_1_obstc15_job6 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 6.0]
gender_1_obstc15_job7 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 7.0]
gender_1_obstc15_job8 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 8.0]
gender_1_obstc15_job9 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 9.0]
gender_1_obstc15_job10 = gender_1_obstc15[gender_1_obstc15['job001_job_code1'] == 10.0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bab273585651> in <cell line: 4>()
#       2
#       3 # gender가 1.0인 데이터
# ----> 4 gender_1 = data1[data1['gender'] == 1.0]
#       5
#       6 # gender가 2.0인 데이터
#
# NameError: name 'data1' is not defined

# %%
# 성별이 여자고 1번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc1_job1 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 1.0]
gender_2_obstc1_job2 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 2.0]
gender_2_obstc1_job3 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 3.0]
gender_2_obstc1_job4 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 4.0]
gender_2_obstc1_job5 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 5.0]
gender_2_obstc1_job6 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 6.0]
gender_2_obstc1_job7 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 7.0]
gender_2_obstc1_job8 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 8.0]
gender_2_obstc1_job9 = gender_2_obstc1[gender_2_obstc1['job001_job_code1'] == 9.0]

# 성별이 여자 2번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc2_job1 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 1.0]
gender_2_obstc2_job2 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 2.0]
gender_2_obstc2_job3 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 3.0]
gender_2_obstc2_job4 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 4.0]
gender_2_obstc2_job5 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 5.0]
gender_2_obstc2_job6 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 6.0]
gender_2_obstc2_job7 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 7.0]
gender_2_obstc2_job8 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 8.0]
gender_2_obstc2_job9 = gender_2_obstc2[gender_2_obstc2['job001_job_code1'] == 9.0]

# 성별이 여자고 3번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc3_job1 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 1.0]
gender_2_obstc3_job2 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 2.0]
gender_2_obstc3_job3 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 3.0]
gender_2_obstc3_job4 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 4.0]
gender_2_obstc3_job5 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 5.0]
gender_2_obstc3_job6 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 6.0]
gender_2_obstc3_job7 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 7.0]
gender_2_obstc3_job8 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 8.0]
gender_2_obstc3_job9 = gender_2_obstc3[gender_2_obstc3['job001_job_code1'] == 9.0]

# 성별이 여자고 4번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc4_job1 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 1.0]
gender_2_obstc4_job2 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 2.0]
gender_2_obstc4_job3 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 3.0]
gender_2_obstc4_job4 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 4.0]
gender_2_obstc4_job5 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 5.0]
gender_2_obstc4_job6 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 6.0]
gender_2_obstc4_job7 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 7.0]
gender_2_obstc4_job8 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 8.0]
gender_2_obstc4_job9 = gender_2_obstc4[gender_2_obstc4['job001_job_code1'] == 9.0]

# 성별이 여자고 5번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc5_job1 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 1.0]
gender_2_obstc5_job2 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 2.0]
gender_2_obstc5_job3 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 3.0]
gender_2_obstc5_job4 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 4.0]
gender_2_obstc5_job5 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 5.0]
gender_2_obstc5_job6 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 6.0]
gender_2_obstc5_job7 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 7.0]
gender_2_obstc5_job8 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 8.0]
gender_2_obstc5_job9 = gender_2_obstc5[gender_2_obstc5['job001_job_code1'] == 9.0]

# 성별이 여자고 6번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc6_job1 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 1.0]
gender_2_obstc6_job2 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 2.0]
gender_2_obstc6_job3 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 3.0]
gender_2_obstc6_job4 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 4.0]
gender_2_obstc6_job5 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 5.0]
gender_2_obstc6_job6 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 6.0]
gender_2_obstc6_job7 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 7.0]
gender_2_obstc6_job8 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 8.0]
gender_2_obstc6_job9 = gender_2_obstc6[gender_2_obstc6['job001_job_code1'] == 9.0]

# 성별이 여자고 7번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc7_job1 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 1.0]
gender_2_obstc7_job2 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 2.0]
gender_2_obstc7_job3 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 3.0]
gender_2_obstc7_job4 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 4.0]
gender_2_obstc7_job5 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 5.0]
gender_2_obstc7_job6 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 6.0]
gender_2_obstc7_job7 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 7.0]
gender_2_obstc7_job8 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 8.0]
gender_2_obstc7_job9 = gender_2_obstc7[gender_2_obstc7['job001_job_code1'] == 9.0]

# 성별이 여자고 8번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc8_job1 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 1.0]
gender_2_obstc8_job2 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 2.0]
gender_2_obstc8_job3 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 3.0]
gender_2_obstc8_job4 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 4.0]
gender_2_obstc8_job5 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 5.0]
gender_2_obstc8_job6 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 6.0]
gender_2_obstc8_job7 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 7.0]
gender_2_obstc8_job8 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 8.0]
gender_2_obstc8_job9 = gender_2_obstc8[gender_2_obstc8['job001_job_code1'] == 9.0]

# 성별이 여자고 9번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc9_job1 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 1.0]
gender_2_obstc9_job2 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 2.0]
gender_2_obstc9_job3 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 3.0]
gender_2_obstc9_job4 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 4.0]
gender_2_obstc9_job5 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 5.0]
gender_2_obstc9_job6 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 6.0]
gender_2_obstc9_job7 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 7.0]
gender_2_obstc9_job8 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 8.0]
gender_2_obstc9_job9 = gender_2_obstc9[gender_2_obstc9['job001_job_code1'] == 9.0]

# 성별이 남자고 10번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc10_job1 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 1.0]
gender_2_obstc10_job2 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 2.0]
gender_2_obstc10_job3 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 3.0]
gender_2_obstc10_job4 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 4.0]
gender_2_obstc10_job5 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 5.0]
gender_2_obstc10_job6 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 6.0]
gender_2_obstc10_job7 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 7.0]
gender_2_obstc10_job8 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 8.0]
gender_2_obstc10_job9 = gender_2_obstc10[gender_2_obstc10['job001_job_code1'] == 9.0]

# 성별이 남자고 11번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc11_job1 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 1.0]
gender_2_obstc11_job2 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 2.0]
gender_2_obstc11_job3 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 3.0]
gender_2_obstc11_job4 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 4.0]
gender_2_obstc11_job5 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 5.0]
gender_2_obstc11_job6 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 6.0]
gender_2_obstc11_job7 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 7.0]
gender_2_obstc11_job8 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 8.0]
gender_2_obstc11_job9 = gender_2_obstc11[gender_2_obstc11['job001_job_code1'] == 9.0]

# 성별이 남자고 12번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc12_job1 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 1.0]
gender_2_obstc12_job2 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 2.0]
gender_2_obstc12_job3 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 3.0]
gender_2_obstc12_job4 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 4.0]
gender_2_obstc12_job5 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 5.0]
gender_2_obstc12_job6 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 6.0]
gender_2_obstc12_job7 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 7.0]
gender_2_obstc12_job8 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 8.0]
gender_2_obstc12_job9 = gender_2_obstc12[gender_2_obstc12['job001_job_code1'] == 9.0]

# 성별이 남자고 13번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc13_job1 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 1.0]
gender_2_obstc13_job2 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 2.0]
gender_2_obstc13_job3 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 3.0]
gender_2_obstc13_job4 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 4.0]
gender_2_obstc13_job5 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 5.0]
gender_2_obstc13_job6 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 6.0]
gender_2_obstc13_job7 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 7.0]
gender_2_obstc13_job8 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 8.0]
gender_2_obstc13_job9 = gender_2_obstc13[gender_2_obstc13['job001_job_code1'] == 9.0]

# 성별이 남자고 14번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc14_job1 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 1.0]
gender_2_obstc14_job2 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 2.0]
gender_2_obstc14_job3 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 3.0]
gender_2_obstc14_job4 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 4.0]
gender_2_obstc14_job5 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 5.0]
gender_2_obstc14_job6 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 6.0]
gender_2_obstc14_job7 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 7.0]
gender_2_obstc14_job8 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 8.0]
gender_2_obstc14_job9 = gender_2_obstc14[gender_2_obstc14['job001_job_code1'] == 9.0]

# 성별이 남자고 15번의 장애를 가지면서 n번의 직업을 가진 데이터
gender_2_obstc15_job1 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 1.0]
gender_2_obstc15_job2 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 2.0]
gender_2_obstc15_job3 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 3.0]
gender_2_obstc15_job4 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 4.0]
gender_2_obstc15_job5 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 5.0]
gender_2_obstc15_job6 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 6.0]
gender_2_obstc15_job7 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 7.0]
gender_2_obstc15_job8 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 8.0]
gender_2_obstc15_job9 = gender_2_obstc15[gender_2_obstc15['job001_job_code1'] == 9.0]

# %%
print(gender_1_obstc1_job1['job001_job_code1'].count())
print(gender_2_obstc1_job1['job001_job_code1'].count())
# Out:
# 50
# 2

# %%
print('----------------------------------------------')
print('지체장애 관리자 직업')
print('남 : ', gender_1_obstc1_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc1_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 전문직 직업')
print('남 : ',gender_1_obstc1_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 사무종사자')
print('남 : ',gender_1_obstc1_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 서비스업')
print('남 : ',gender_1_obstc1_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 판매종사자')
print('남 : ',gender_1_obstc1_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 농림 어업 종사자')
print('남 : ',gender_1_obstc1_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc1_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc1_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('지체장애 단순노무 종사자')
print('남 : ',gender_1_obstc1_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc1_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 지체장애 관리자 직업
# 남 :  50
# 여 :  2
# ----------------------------------------------
# 지체장애 전문직 직업
# 남 :  108
# 여 :  57
# ----------------------------------------------
# 지체장애 사무종사자
# 남 :  159
# 여 :  50
# ----------------------------------------------
# 지체장애 서비스업
# 남 :  56
# 여 :  77
# ----------------------------------------------
# 지체장애 판매종사자
# 남 :  128
# 여 :  42
# ----------------------------------------------
# 지체장애 농림 어업 종사자
# 남 :  29
# 여 :  10
# ----------------------------------------------
# 지체장애 기능원 및 관련 기능 종사자
# 남 :  158
# 여 :  13
# ----------------------------------------------
# 지체장애 장치·기계 조작 및 조립 종사자
# 남 :  167
# 여 :  8
# ----------------------------------------------
# 지체장애 단순노무 종사자
# 남 :  160
# 여 :  76

# %%
print('----------------------------------------------')
print('뇌병변장애 관리자 직업')
print('남 : ', gender_1_obstc2_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc2_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변장애 전문직 직업')
print('남 : ',gender_1_obstc2_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변장애 사무종사자')
print('남 : ',gender_1_obstc2_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변 장애 서비스업')
print('남 : ',gender_1_obstc2_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변 장애 판매 종사자')
print('남 : ',gender_1_obstc2_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc2_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc2_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc2_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌병변 장애 단순노무 종사자')
print('남 : ',gender_1_obstc2_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc2_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 뇌병변장애 관리자 직업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 뇌병변장애 전문직 직업
# 남 :  6
# 여 :  4
# ----------------------------------------------
# 뇌병변장애 사무종사자
# 남 :  24
# 여 :  5
# ----------------------------------------------
# 뇌병변 장애 서비스업
# 남 :  5
# 여 :  6
# ----------------------------------------------
# 뇌병변 장애 판매 종사자
# 남 :  7
# 여 :  2
# ----------------------------------------------
# 뇌병변 장애 농림 어업 종사자
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 뇌병변 장애 기능원 및 관련 기능 종사자
# 남 :  5
# 여 :  1
# ----------------------------------------------
# 뇌병변 장애 장치·기계 조작 및 조립 종사자
# 남 :  9
# 여 :  0
# ----------------------------------------------
# 뇌병변 장애 단순노무 종사자
# 남 :  25
# 여 :  8

# %%
print('----------------------------------------------')
print('시각장애 관리자 직업')
print('남 : ', gender_1_obstc3_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc3_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('시각장애 전문직 직업')
print('남 : ',gender_1_obstc3_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 사무종사자')
print('남 : ',gender_1_obstc3_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 서비스 종사자')
print('남 : ',gender_1_obstc3_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 판매 종사자')
print('남 : ',gender_1_obstc3_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc3_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc3_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc3_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('시각 장애 단순노무 종사자')
print('남 : ',gender_1_obstc3_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc3_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 시각장애 관리자 직업
# 남 :  4
# 여 :  3
# ----------------------------------------------
# 시각장애 전문직 직업
# 남 :  60
# 여 :  29
# ----------------------------------------------
# 시각 장애 사무종사자
# 남 :  27
# 여 :  26
# ----------------------------------------------
# 시각 장애 서비스 종사자
# 남 :  13
# 여 :  14
# ----------------------------------------------
# 시각 장애 판매 종사자
# 남 :  21
# 여 :  14
# ----------------------------------------------
# 시각 장애 농림 어업 종사자
# 남 :  7
# 여 :  4
# ----------------------------------------------
# 시각 장애 기능원 및 관련 기능 종사자
# 남 :  23
# 여 :  3
# ----------------------------------------------
# 시각 장애 장치·기계 조작 및 조립 종사자
# 남 :  17
# 여 :  0
# ----------------------------------------------
# 시각 장애 단순노무 종사자
# 남 :  57
# 여 :  15

# %%
print('----------------------------------------------')
print('청각 장애 관리자 직업')
print('남 : ', gender_1_obstc4_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc4_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 전문직 직업')
print('남 : ',gender_1_obstc4_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 사무종사자')
print('남 : ',gender_1_obstc4_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 서비스업')
print('남 : ',gender_1_obstc4_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 판매 종사자')
print('남 : ',gender_1_obstc4_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc4_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc4_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc4_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('청각 장애 단순노무 종사자')
print('남 : ',gender_1_obstc4_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc4_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 청각 장애 관리자 직업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 청각 장애 전문직 직업
# 남 :  15
# 여 :  8
# ----------------------------------------------
# 청각 장애 사무종사자
# 남 :  14
# 여 :  14
# ----------------------------------------------
# 청각 장애 서비스업
# 남 :  4
# 여 :  13
# ----------------------------------------------
# 청각 장애 판매 종사자
# 남 :  2
# 여 :  13
# ----------------------------------------------
# 청각 장애 농림 어업 종사자
# 남 :  6
# 여 :  1
# ----------------------------------------------
# 청각 장애 기능원 및 관련 기능 종사자
# 남 :  21
# 여 :  2
# ----------------------------------------------
# 청각 장애 장애 장치·기계 조작 및 조립 종사자
# 남 :  18
# 여 :  2
# ----------------------------------------------
# 청각 장애 단순노무 종사자
# 남 :  33
# 여 :  30

# %%
print('----------------------------------------------')
print('언어 장애 관리자 직업')
print('남 : ', gender_1_obstc5_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc5_job1['job001_job_code1'].count())
print('---------------------------------------------')
print('언어 장애 전문직 직업')
print('남 : ',gender_1_obstc5_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 사무종사자')
print('남 : ',gender_1_obstc5_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 서비스업')
print('남 : ',gender_1_obstc5_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 판매 종사자')
print('남 : ',gender_1_obstc5_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc5_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc5_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc5_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('언어 장애 9번의 단순노무 종사자')
print('남 : ',gender_1_obstc5_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc5_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 언어 장애 관리자 직업
# 남 :  2
# 여 :  1
# ---------------------------------------------
# 언어 장애 전문직 직업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 언어 장애 사무종사자
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 언어 장애 서비스업
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 언어 장애 판매 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 언어 장애 농림 어업 종사자
# 남 :  2
# 여 :  1
# ----------------------------------------------
# 언어 장애 장애 기능원 및 관련 기능 종사자
# 남 :  6
# 여 :  1
# ----------------------------------------------
# 언어 장애 장치·기계 조작 및 조립 종사자
# 남 :  4
# 여 :  1
# ----------------------------------------------
# 언어 장애 9번의 단순노무 종사자
# 남 :  7
# 여 :  1

# %%
print('----------------------------------------------')
print('지적 장애 관리자 직업')
print('남 : ', gender_1_obstc6_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc6_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 전문직 직업')
print('남 : ',gender_1_obstc6_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 사무종사자')
print('남 : ',gender_1_obstc6_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 서비스업')
print('남 : ',gender_1_obstc6_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 판매 종사자')
print('남 : ',gender_1_obstc6_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc6_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc6_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc6_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('지적 장애 단순노무 종사자')
print('남 : ',gender_1_obstc6_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc6_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 지적 장애 관리자 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 지적 장애 전문직 직업
# 남 :  2
# 여 :  1
# ----------------------------------------------
# 지적 장애 사무종사자
# 남 :  7
# 여 :  4
# ----------------------------------------------
# 지적 장애 서비스업
# 남 :  7
# 여 :  6
# ----------------------------------------------
# 지적 장애 판매 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 지적 장애 농림 어업 종사자
# 남 :  3
# 여 :  1
# ----------------------------------------------
# 지적 장애 기능원 및 관련 기능 종사자
# 남 :  6
# 여 :  0
# ----------------------------------------------
# 지적 장애 장치·기계 조작 및 조립 종사자
# 남 :  4
# 여 :  0
# ----------------------------------------------
# 지적 장애 단순노무 종사자
# 남 :  71
# 여 :  22

# %%
print('----------------------------------------------')
print('발달 장애 관리자 직업')
print('남 : ', gender_1_obstc7_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc7_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 전문직 직업')
print('남 : ',gender_1_obstc7_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 사무종사자')
print('남 : ',gender_1_obstc7_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 서비스업')
print('남 : ',gender_1_obstc7_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 판매 종사자')
print('남 : ',gender_1_obstc7_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc7_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc7_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('발달 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc7_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job8['job001_job_code1'].count())
print('---------------------------------------------')
print('발달 장애 단순노무 종사자')
print('남 : ',gender_1_obstc7_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc7_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 발달 장애 관리자 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 발달 장애 전문직 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 발달 장애 사무종사자
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 발달 장애 서비스업
# 남 :  3
# 여 :  0
# ----------------------------------------------
# 발달 장애 판매 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 발달 장애 농림 어업 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 발달 장애 기능원 및 관련 기능 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 발달 장애 장치·기계 조작 및 조립 종사자
# 남 :  0
# 여 :  0
# ---------------------------------------------
# 발달 장애 단순노무 종사자
# 남 :  5
# 여 :  0

# %%
print('----------------------------------------------')
print('정신 장애 관리자 직업')
print('남 : ', gender_1_obstc8_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc8_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 전문직 직업')
print('남 : ',gender_1_obstc8_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 사무종사자')
print('남 : ',gender_1_obstc8_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 서비스업')
print('남 : ',gender_1_obstc8_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 판매 종사자')
print('남 : ',gender_1_obstc8_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc8_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc8_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc8_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('정신 장애 단순노무 종사자')
print('남 : ',gender_1_obstc8_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc8_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 정신 장애 관리자 직업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 정신 장애 전문직 직업
# 남 :  0
# 여 :  2
# ----------------------------------------------
# 정신 장애 사무종사자
# 남 :  0
# 여 :  1
# ----------------------------------------------
# 정신 장애 서비스업
# 남 :  0
# 여 :  1
# ----------------------------------------------
# 정신 장애 판매 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 정신 장애 농림 어업 종사자
# 남 :  0
# 여 :  2
# ----------------------------------------------
# 정신 장애 기능원 및 관련 기능 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 정신 장애 장치·기계 조작 및 조립 종사자
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 정신 장애 단순노무 종사자
# 남 :  9
# 여 :  8

# %%
print('----------------------------------------------')
print('신장 장애 관리자 직업')
print('남 : ', gender_1_obstc9_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc9_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 전문직 직업')
print('남 : ',gender_1_obstc9_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 사무종사자')
print('남 : ',gender_1_obstc9_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 서비스업')
print('남 : ',gender_1_obstc9_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 판매 종사자')
print('남 : ',gender_1_obstc9_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc9_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc9_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc9_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('신장 장애 단순노무 종사자')
print('남 : ',gender_1_obstc9_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc9_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 신장 장애 관리자 직업
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 신장 장애 전문직 직업
# 남 :  10
# 여 :  3
# ----------------------------------------------
# 신장 장애 사무종사자
# 남 :  12
# 여 :  11
# ----------------------------------------------
# 신장 장애 서비스업
# 남 :  1
# 여 :  6
# ----------------------------------------------
# 신장 장애 판매 종사자
# 남 :  6
# 여 :  2
# ----------------------------------------------
# 신장 장애 농림 어업 종사자
# 남 :  3
# 여 :  1
# ----------------------------------------------
# 신장 장애 기능원 및 관련 기능 종사자
# 남 :  3
# 여 :  0
# ----------------------------------------------
# 신장 장애 장애 장치·기계 조작 및 조립 종사자
# 남 :  11
# 여 :  0
# ----------------------------------------------
# 신장 장애 단순노무 종사자
# 남 :  14
# 여 :  2

# %%
print('----------------------------------------------')
print('심장 장애 관리자 직업')
print('남 : ', gender_1_obstc10_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc10_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 전문직 직업')
print('남 : ',gender_1_obstc10_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 사무종사자')
print('남 : ',gender_1_obstc10_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 서비스업')
print('남 : ',gender_1_obstc10_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 판매 종사자')
print('남 : ',gender_1_obstc10_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc10_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc10_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc10_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('심장 장애 장애 단순노무 종사자')
print('남 : ',gender_1_obstc10_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc10_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 심장 장애 관리자 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 심장 장애 전문직 직업
# 남 :  0
# 여 :  1
# ----------------------------------------------
# 심장 장애 사무종사자
# 남 :  1
# 여 :  3
# ----------------------------------------------
# 심장 장애 서비스업
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 심장 장애 판매 종사자
# 남 :  0
# 여 :  2
# ----------------------------------------------
# 심장 장애 농림 어업 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 심장 장애 기능원 및 관련 기능 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 심장 장애 장치·기계 조작 및 조립 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 심장 장애 장애 단순노무 종사자
# 남 :  2
# 여 :  0

# %%
print('----------------------------------------------')
print('호흡기 장애 관리자 직업')
print('남 : ', gender_1_obstc11_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc11_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 전문직 직업')
print('남 : ',gender_1_obstc11_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 사무종사자')
print('남 : ',gender_1_obstc11_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 서비스업')
print('남 : ',gender_1_obstc11_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 판매 종사자')
print('남 : ',gender_1_obstc11_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc11_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc11_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc11_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('호흡기 장애 단순노무 종사자')
print('남 : ',gender_1_obstc11_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc11_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 호흡기 장애 관리자 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 전문직 직업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 사무종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 서비스업
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 호흡기 장애 판매 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 농림 어업 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 기능원 및 관련 기능 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 장치·기계 조작 및 조립 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 호흡기 장애 단순노무 종사자
# 남 :  2
# 여 :  0

# %%
print('----------------------------------------------')
print('간 장애 관리자 직업')
print('남 : ', gender_1_obstc12_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc12_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애 전문직 직업')
print('남 : ',gender_1_obstc12_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애 사무종사자')
print('남 : ',gender_1_obstc12_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애 서비스업')
print('남 : ',gender_1_obstc12_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job4['job001_job_code1'].count())
print('---------------------------------------------')
print('간 장애 판매 종사자')
print('남 : ',gender_1_obstc12_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc12_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc12_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc12_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('간 장애 단순노무 종사자')
print('남 : ',gender_1_obstc12_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc12_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 간 장애 관리자 직업
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 간 장애 전문직 직업
# 남 :  3
# 여 :  1
# ----------------------------------------------
# 간 장애 사무종사자
# 남 :  3
# 여 :  2
# ----------------------------------------------
# 간 장애 서비스업
# 남 :  2
# 여 :  0
# ---------------------------------------------
# 간 장애 판매 종사자
# 남 :  0
# 여 :  1
# ----------------------------------------------
# 간 장애 농림 어업 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 간 장애 기능원 및 관련 기능 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 간 장애장치·기계 조작 및 조립 종사자
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 간 장애 단순노무 종사자
# 남 :  1
# 여 :  1

# %%
print('----------------------------------------------')
print('안면 장애 관리자 직업')
print('남 : ', gender_1_obstc13_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc13_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 전문직 직업')
print('남 : ',gender_1_obstc13_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 사무종사자')
print('남 : ',gender_1_obstc13_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 서비스업')
print('남 : ',gender_1_obstc13_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 판매 종사자')
print('남 : ',gender_1_obstc13_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc13_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc13_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc13_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('안면 장애 단순노무 종사자')
print('남 : ',gender_1_obstc13_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc13_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 안면 장애 관리자 직업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 안면 장애 전문직 직업
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 안면 장애 사무종사자
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 안면 장애 서비스업
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 안면 장애 판매 종사자
# 남 :  0
# 여 :  1
# ----------------------------------------------
# 안면 장애 농림 어업 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 안면 장애 기능원 및 관련 기능 종사자
# 남 :  4
# 여 :  0
# ----------------------------------------------
# 안면 장애 장치·기계 조작 및 조립 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 안면 장애 단순노무 종사자
# 남 :  1
# 여 :  0

# %%
print('----------------------------------------------')
print('장루요루 장애 관리자 직업')
print('남 : ', gender_1_obstc14_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc14_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 전문직 직업')
print('남 : ',gender_1_obstc14_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job2['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 사무종사자')
print('남 : ',gender_1_obstc14_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 서비스업')
print('남 : ',gender_1_obstc14_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 판매 종사자')
print('남 : ',gender_1_obstc14_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc14_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc14_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc14_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('장루요루 장애 단순노무 종사자')
print('남 : ',gender_1_obstc14_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc14_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 장루요루 장애 관리자 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 전문직 직업
# 남 :  0
# 여 :  3
# ----------------------------------------------
# 장루요루 장애 사무종사자
# 남 :  2
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 서비스업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 판매 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 농림 어업 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 기능원 및 관련 기능 종사자
# 남 :  3
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 장치·기계 조작 및 조립 종사자
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 장루요루 장애 단순노무 종사자
# 남 :  0
# 여 :  0

# %%
print('----------------------------------------------')
print('뇌전증 장애 관리자 직업')
print('남 : ', gender_1_obstc15_job1['job001_job_code1'].count())
print('여 : ', gender_2_obstc15_job1['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 전문직 직업')
print('남 : ',gender_1_obstc15_job2['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job2['job001_job_code1'].count())
print('---------------------------------------------')
print('뇌전증 장애 사무종사자')
print('남 : ',gender_1_obstc15_job3['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job3['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 서비스업')
print('남 : ',gender_1_obstc15_job4['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job4['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 판매 종사자')
print('남 : ',gender_1_obstc15_job5['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job5['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 농림 어업 종사자')
print('남 : ',gender_1_obstc15_job6['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job6['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 기능원 및 관련 기능 종사자')
print('남 : ',gender_1_obstc15_job7['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job7['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 장치·기계 조작 및 조립 종사자')
print('남 : ',gender_1_obstc15_job8['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job8['job001_job_code1'].count())
print('----------------------------------------------')
print('뇌전증 장애 단순노무 종사자')
print('남 : ',gender_1_obstc15_job9['job001_job_code1'].count())
print('여 : ',gender_2_obstc15_job9['job001_job_code1'].count())
# Out:
# ----------------------------------------------
# 뇌전증 장애 관리자 직업
# 남 :  0
# 여 :  0
# ----------------------------------------------
# 뇌전증 장애 전문직 직업
# 남 :  0
# 여 :  0
# ---------------------------------------------
# 뇌전증 장애 사무종사자
# 남 :  1
# 여 :  2
# ----------------------------------------------
# 뇌전증 장애 서비스업
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 뇌전증 장애 판매 종사자
# 남 :  1
# 여 :  1
# ----------------------------------------------
# 뇌전증 장애 농림 어업 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 뇌전증 장애 기능원 및 관련 기능 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 뇌전증 장애 장치·기계 조작 및 조립 종사자
# 남 :  1
# 여 :  0
# ----------------------------------------------
# 뇌전증 장애 단순노무 종사자
# 남 :  6
# 여 :  2

# %%
df = pd.DataFrame(data1)

# CSV 파일로 저장
df.to_csv('data.csv', index=False)

# %%
df = pd.DataFrame(data_cleaned)

# 엑셀 파일로 저장
df.to_excel('찐 장애별 직군 인구수.xlsx', index=False)

# %%
df.to_csv('/path/to/save/data.csv', index=False)
